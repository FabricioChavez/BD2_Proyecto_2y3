# %%
import nltk
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import PorterStemmer
from nltk.data import find
from nltk.corpus import stopwords
import os
import pandas as pd

current_dir = os.getcwd()

if current_dir not in nltk.data.path:
    nltk.data.path.append(current_dir)


nltk.download("punkt", download_dir=current_dir)

stemmer = SnowballStemmer("english")
# Out:
# [nltk_data] Downloading package punkt to c:\Users\Jesus
# [nltk_data]     Egusquiza\Desktop\CICLO6\BD II\proyeccto2...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Generando el SPIMI

# %%
from Spimi import SPIMIIndex
df = pd.read_csv("data_final.csv")
documents = df["merge"].dropna().tolist()  # Asegúrate de eliminar valores NaN
collection = len(documents)  # Número de documentos en la colección
print("Número de documentos en la colección:", collection)
memory_limit = 500000  # Límite de memoria en bytes
index = SPIMIIndex(memory_limit=memory_limit, collection=collection)
merged_index = index.construct_index(documents)
# Out:
# Número de documentos en la colección: 70917
# Indexing...
# Merging blocks...

# %% [markdown]
# ## Probando Consulta

# %%
query = "Yuki college student"

lista = index.retrieve_index(query)

print("lista", lista)
# Out:
# Query: ['yuki', 'colleg', 'student']
# ...

# %%
lista = dict(list(lista.items())[:5])
# buscar en csv
df = pd.read_csv("data_merge2.csv")
for doc_id in lista:
    print(df.loc[doc_id, "merge"])
    texts = df.loc[doc_id, "merge"]
    tokens = index.preprocess_text(texts)
    print(tokens)
    print("\n")
# Out:
# College student Aoi collapsed due to anemia, but she was saved by a young man named Daiki, who is also the shopkeeper of a small restaurant called “Yuki Usagi”. Due to some circumstances, Aoi became unable to eat meals. Nonetheless, her heart is drawn to how Daiki cooks dishes and eats them. Romance, Shoujo, Slice of Life, Food and Beverage, Based on a Novel
# ['colleg', 'student', 'aoi', 'collaps', 'due', 'anemia', 'save', 'young', 'man', 'name', 'daiki', 'also', 'shopkeep', 'small', 'restaur', 'call', 'yuki', 'usagi', 'due', 'circumst', 'aoi', 'becam', 'unabl', 'eat', 'meal', 'nonetheless', 'heart', 'drawn', 'daiki', 'cook', 'dish', 'eat', 'romanc', 'shoujo', 'slice', 'life', 'food', 'beverag', 'base', 'novel']
#
#
# ...
